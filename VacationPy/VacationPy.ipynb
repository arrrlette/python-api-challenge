# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint
#gmaps.configure(api_key="AI...")

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_df_path = "Weather_DF.csv"
weather_df = pd.read_csv(weather_df_path)

weather_df
# Out:
#      Unnamed: 0         City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0             0   Bredasdorp -34.53   20.04     48.20        81         100
# 1             1      Mataura -46.19  168.86     39.00        83         100
# 2             2  Kangaatsiaq  68.31  -53.46     41.76        92          96
# 3             3       Albany  42.60  -73.97     89.01        37           4
# 4             4    Mahébourg -20.41   57.70     69.80        88          40
# ..          ...          ...    ...     ...       ...       ...         ...
# 584         584   Udon Thani  17.42  102.79     77.61        85         100
# 585         585  Preeceville  51.95 -102.67     66.02        75          59
# 586         586       Areosa  41.72   -8.86     80.01        54           0
# 587         587      Tautira -17.73 -149.15     78.80        78          75
# 588         588       Fillan  63.61    8.97     55.40        66          75
#
#      Wind Speed Country        Date
# 0         17.22      ZA  1594671400
# 1          3.00      NZ  1594671566
# 2         16.28      GL  1594671652
# 3          1.01      US  1594671492
# 4         11.41      MU  1594671606
# ..          ...     ...         ...
# 584        4.05      TH  1594671733
# 585       13.24      CA  1594671734
# 586        4.70      PT  1594671734
# 587        6.93      PF  1594671734
# 588        3.36      NO  1594671734
#
# [589 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#configure gmaps
gmaps.configure(api_key=g_key)

# %%
#store latitude and longitude in locations
city_locations = weather_df[["Lat","Lng"]]
#store humidity as a variable
humidity = weather_df['Humidity']
max_humidity = max(humidity)
max_humidity
# Out:
# 100

# %%
#plot heatmap
fig = gmaps.figure()

#create heat layer
heat_layer = gmaps.heatmap_layer(city_locations, weights = humidity, dissipating=False, max_intensity=max_humidity, point_radius=1)
#heat_layer.max_intensity = max_humidity

#add layer
fig.add_layer(heat_layer)

#display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Narrow down the DataFrame to find your ideal weather condition. For example:
#A max temperature lower than 80 degrees but higher than 70.
#Wind speed less than 10 mph.
#Zero cloudiness.
#Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.

ideal_df = weather_df.loc[(weather_df['Max Temp'] <85) & (weather_df['Max Temp'] > 70) & (weather_df['Wind Speed'] <10) & (weather_df['Cloudiness'] < 5)]
ideal_df
# Out:
#      Unnamed: 0                      City    Lat     Lng  Max Temp  Humidity  \
# 12           12              Port-de-Bouc  43.40    4.98     77.00        47
# 69           69                  Lithakia  37.72   20.83     80.60        47
# 86           86                   Jackson  42.42 -122.83     84.00        36
# 122         122           Arraial do Cabo -22.97  -42.03     78.80        65
# 132         132                    Ürümqi  43.80   87.60     73.40        40
# 143         143                    Polson  47.69 -114.16     73.99        42
# 147         147                Baker City  44.77 -117.83     77.00        23
# 153         153                      Lata  40.16   -8.33     82.00        55
# 174         174                  Plátanos  37.67   21.62     78.80        78
# 199         199                 Sinnamary   5.38  -52.95     82.45        75
# 253         253                     Sīwah  29.20   25.52     84.49        23
# 274         274                Cavalcante -13.80  -47.46     80.80        25
# 312         312                 Caravelas -17.71  -39.25     75.24        79
# 341         341                  Vallenar -28.57  -70.76     72.93        33
# 356         356                     Kumul  42.80   93.45     73.42        28
# 381         381              Marsá Maţrūḩ  31.35   27.25     77.00        73
# 437         437                Vila Velha -20.33  -40.29     80.60        65
# 439         439  São José da Coroa Grande  -8.90  -35.15     76.96        77
# 441         441                Valparaíso -33.04  -71.63     78.80        24
# 444         444                    Bukama  -9.20   25.85     75.52        29
# 445         445                    Chaman  30.92   66.45     76.14        31
# 478         478                     Cieza  38.24   -1.42     80.01        69
# 479         479                   Yetkul'  54.82   61.59     71.60        60
# 496         496              Oktyabr'skiy  54.48   53.47     73.00        87
# 501         501          Diego de Almagro -26.37  -70.05     76.68        21
# 527         527                   Labuhan  -6.88  112.21     76.21        86
# 579         579                     Seydi  39.48   62.91     84.06        15
# 583         583                Tursunzoda  38.51   68.23     71.60        53
# 586         586                    Areosa  41.72   -8.86     80.01        54
#
#      Cloudiness  Wind Speed Country        Date
# 12            0        5.82      FR  1594671653
# 69            0        8.05      GR  1594671662
# 86            1        6.93      US  1594671664
# 122           0        6.93      BR  1594671405
# 132           0        8.95      CN  1594671423
# 143           0        8.72      US  1594671671
# 147           1        9.17      US  1594671672
# 153           0        4.00      PT  1594671673
# 174           0        2.86      GR  1594671675
# 199           4        8.93      GF  1594671679
# 253           0        6.44      EG  1594671686
# 274           0        6.82      BR  1594671689
# 312           0        5.39      BR  1594671694
# 341           0        4.79      CL  1594671698
# 356           0        7.92      CN  1594671701
# 381           0        5.82      EG  1594671704
# 437           0        8.05      BR  1594671709
# 439           1        6.15      BR  1594671713
# 441           0        8.05      CL  1594671713
# 444           0        4.18      CD  1594671713
# 445           0        9.44      PK  1594671714
# 478           0        5.01      ES  1594671719
# 479           0        4.47      RU  1594671719
# 496           0        6.26      RU  1594671721
# 501           0        8.30      CL  1594671470
# 527           1        7.27      ID  1594671726
# 579           0        9.28      TM  1594671733
# 583           0        2.24      TJ  1594671733
# 586           0        4.70      PT  1594671734

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#create new hotel DF
hotel_df = ideal_df[["City", "Lat", "Lng", "Country"]].copy()

#add hotel column to df
hotel_df['Hotel Name'] = ""
hotel_df['Hotel Lat'] = ""
hotel_df['Hotel Lng'] = ""


#parameters
#keyword = "hotel"
target_type = "lodging"
radius = 5000

params = {
    #"keyword": keyword,
    "type": target_type,
    "radius": radius,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

for index, row in hotel_df.iterrows():
    
    #set variables for lat and lng to include in parameters. also setting variable for city for each row
    lat = row["Lat"]
    lng = row["Lng"]
    city = row["City"]
    
    #add lat/lng to parameters - values must be a string
    #copy
 
    #assemble url and make API request
    print(f"Retrieving results for {city}: ")
    response = requests.get(base_url, params=params).json()
    
    #extract results
    results = response['results']
        
    try:
        print(f"Closest hotel for {city} is {results[0]['name']}.")
        
        #add hotel to Hotel Name column in the df
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
        #add hotel lat and long to dataframe
        hotel_df.loc[index, 'Hotel Lat'] = results[0]['geometry']['location']['lat']
        hotel_df.loc[index, 'Hotel Lng'] = results[0]['geometry']['location']['lng']
                
        
    except(KeyError, IndexError):
        
        #print statement if hotel is not found       
        print("Missing results...skipping")
        
        #if a hotel name is not found, add "N/A" to hotel name field in dataframe
        hotel_df.loc[index, "Hotel Name"] = "N/A"
        
        #if hotel name is not found, default to city coordinates for Lat/Lng fields in the dataframe. The reason
        #for this is that we need to convert the lat/lng to floats and we will get an error if it finds a blank field
        hotel_df.loc[index, "Hotel Lat"] = hotel_df.loc[index,"Lat"]
        hotel_df.loc[index, "Hotel Lng"] = hotel_df.loc[index, "Lng"]
    
    print("---------------")
# Out:
# Retrieving results for Port-de-Bouc:
# Closest hotel for Port-de-Bouc is HOTEL RESIDENCE LES AIGUADES.
# ---------------
# Retrieving results for Lithakia:
# Closest hotel for Lithakia is Zante Plaza Hotel & Apartments.
# ---------------
# Retrieving results for Jackson:
# Closest hotel for Jackson is Agate Village Apartments.
# ---------------
# Retrieving results for Arraial do Cabo:
# Closest hotel for Arraial do Cabo is Pousada Porto Praia.
# ---------------
# Retrieving results for Ürümqi:
# Closest hotel for Ürümqi is Hua Ling Grand Hotel Urumqi.
# ---------------
# Retrieving results for Polson:
# Closest hotel for Polson is Americas Best Value Port Polson Inn.
# ---------------
# Retrieving results for Baker City:
# Closest hotel for Baker City is Bridge Street Inn.
# ---------------
# Retrieving results for Lata:
# Closest hotel for Lata is Casa Maquia.
# ---------------
# Retrieving results for Plátanos:
# Closest hotel for Plátanos is Hotel Kronio.
# ---------------
# Retrieving results for Sinnamary:
# Closest hotel for Sinnamary is ALETHEIA Appartement Sinnamary.
# ---------------
# Retrieving results for Sīwah:
# Closest hotel for Sīwah is Qasr Alzaytuna Inn.
# ---------------
# Retrieving results for Cavalcante:
# Closest hotel for Cavalcante is Pousada Vila dos Ipês.
# ---------------
# Retrieving results for Caravelas:
# Closest hotel for Caravelas is Pousada dos Navegantes.
# ---------------
# Retrieving results for Vallenar:
# Closest hotel for Vallenar is Humacao Bed & Breakfast.
# ---------------
# Retrieving results for Kumul:
# Closest hotel for Kumul is Laoyutang Resort.
# ---------------
# Retrieving results for Marsá Maţrūḩ:
# Closest hotel for Marsá Maţrūḩ is Beau Site.
# ---------------
# Retrieving results for Vila Velha:
# Closest hotel for Vila Velha is Hotel Vitória Palace.
# ---------------
# Retrieving results for São José da Coroa Grande:
# Closest hotel for São José da Coroa Grande is Crôa Mares Hotel.
# ---------------
# Retrieving results for Valparaíso:
# Closest hotel for Valparaíso is Hotel Ultramar.
# ---------------
# Retrieving results for Bukama:
# Missing results...skipping
# ---------------
# Retrieving results for Chaman:
# Closest hotel for Chaman is Niamatt parda Center.
# ---------------
# Retrieving results for Cieza:
# Closest hotel for Cieza is Hotel San Sebastián Hospedería.
# ---------------
# Retrieving results for Yetkul':
# Closest hotel for Yetkul' is Баден-Баден Термы Еткуль.
# ---------------
# Retrieving results for Oktyabr'skiy:
# Closest hotel for Oktyabr'skiy is Уязы-Тау гостиница.
# ---------------
# Retrieving results for Diego de Almagro:
# Closest hotel for Diego de Almagro is hotel luna del desierto.
# ---------------
# Retrieving results for Labuhan:
# Closest hotel for Labuhan is bador sepret.
# ---------------
# Retrieving results for Seydi:
# Missing results...skipping
# ---------------
# Retrieving results for Tursunzoda:
# Closest hotel for Tursunzoda is Stoyanka Charli.
# ---------------
# Retrieving results for Areosa:
# Closest hotel for Areosa is Hotel Flôr de Sal.
# ---------------

# %%
hotel_df
# Out:
# Pretty printing has been turned ON

# %%
pprint(response)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAAJE_kQMjTfJFDkiYFWEw08j-8VA8RkLpe7H8T3AuM0526UCbS1iCyDdS0_vwn7ecxd1bU4utDyaIOQaefugVeqC5L-07TSZeqk1txgObqk0B-Q6TM6Chm1iMqiZn1b5-pgSPE1-stBs-isAJMTNI8i7NFQV-YF9jAl8edOOTzbhH5YuXO3b7qpiN8yF_e8RcWWAZGL74WGbivJzfq1Q7NxBIC8WEQLO1G6vq4a0bpbQGKICGmk7-SJbOE4Sne3-TB-A-n6QZ1FcbwNF7hMMSLFnPQPwWyIPY6GWRIgpzRB7IGpj-pA5W72Mm4HnFHXysEALEoaHhHdvBETIoQhDZ6FvLLGOcbbYk038bjbBrRcztBn87htmekZu-519sH_eRrRIQi9lGn9hGpRXJtBLk9WOouxoUGYYfXXLYraZZ1qrEsVyBH0Sbx0k',
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.69227790000001,
#                                         'lng': -8.8481293},
#                            'viewport': {'northeast': {'lat': 41.69365063029149,
#                                                       'lng': -8.846597269708495},
#                                         'southwest': {'lat': 41.69095266970849,
#                                                       'lng': -8.8492952302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '089a306dc5423c09a049688f69bbff1911cd4d5d',
#               'name': 'Hotel Flôr de Sal',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2432,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118002686377751169682">André '
#                                                 'Pestana Andrade</a>'],
#                           'photo_reference': 'CmRaAAAA0hVBbCyWGXRE5uH7CwcQOniSarjQpQLSkngv-pK7gF4H4OBlCfCBRcjZsEhpPXjEpS7HB9Ej2HuD7QKcodXEua-sjEYsZf-8XDtmaOm2-iRRLtIRf8x_eOOAlmbfOcUxEhBBxiONktMsbLyAC8R8178lGhR2axBGLZa-iiwuMH73qu5827m6Bg',
#                           'width': 3286}],
#               'place_id': 'ChIJUxoCHdDJJQ0R-5_vqjlzMvE',
#               'plus_code': {'compound_code': 'M5R2+WP Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5R2+WP'},
#               'rating': 4.4,
#               'reference': 'ChIJUxoCHdDJJQ0R-5_vqjlzMvE',
#               'scope': 'GOOGLE',
#               'types': ['spa',
#                         'lodging',
#                         'restaurant',
#                         'food',
#                         'gym',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 543,
#               'vicinity': 'Avenida de Cabo Verde 100, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.70352800000001,
#                                         'lng': -8.8357514},
#                            'viewport': {'northeast': {'lat': 41.70493303029151,
#                                                       'lng': -8.834393669708497},
#                                         'southwest': {'lat': 41.70223506970851,
#                                                       'lng': -8.837091630291502}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'a06e63de84d294f62304927f5ece5894cb8f59ec',
#               'name': 'Pousada Viana do Castelo',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 880,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108288322725571522994">Pousada '
#                                                 'Viana do Castelo</a>'],
#                           'photo_reference': 'CmRaAAAAKi3MakIOTpSzDckaEC4Jid1L_pwNySdTMKPgDuWckdp5GZB3O_Ov0nr7GVnoMYCDL90HWyVzPx4B8s7KQCG45dESVR3cqTUu6Xqoy4o9sHmhnKHDq0DPDWCVb5nFfJJtEhAZeyIrKWx57wH80zZmOI8fGhRWChokHMIfCYrENilTXk9p0FlIzg',
#                           'width': 1322}],
#               'place_id': 'ChIJtY5ix9fJJQ0RbT9Db1ezrUY',
#               'plus_code': {'compound_code': 'P537+CM Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHP537+CM'},
#               'rating': 4.7,
#               'reference': 'ChIJtY5ix9fJJQ0RbT9Db1ezrUY',
#               'scope': 'GOOGLE',
#               'types': ['lodging',
#                         'restaurant',
#                         'food',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 809,
#               'vicinity': 'Monte de Santa Luzia, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.70250720000001,
#                                         'lng': -8.819721900000001},
#                            'viewport': {'northeast': {'lat': 41.70398438029149,
#                                                       'lng': -8.818480519708498},
#                                         'southwest': {'lat': 41.7012864197085,
#                                                       'lng': -8.821178480291502}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '4078f48806973122313b0389efa5db08c0394d14',
#               'name': 'Axis Viana - Business & SPA Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1246,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103771433411371018209">AXIS '
#                                                 'VIANA BUSINESS &amp; SPA '
#                                                 'HOTEL</a>'],
#                           'photo_reference': 'CmRaAAAARVtO-BajclOzgnTwPKoUWg0592HXfeWbWYbjWMwt_l5JgNDfxR05uOTul7Im9KfQAfIbqpRI5cQo9dacyLNjtQIrI9kfkpb4YwRdUyGVy8R94jYA7M4fxtg99HbfMq74EhDA8qm5vzaKPZtTJBjMeKR8GhQUTO-NAie_CoGBguXqneCs7x6SLg',
#                           'width': 3308}],
#               'place_id': 'ChIJY1Zjmsu3JQ0Rwqt-QxhJhY0',
#               'plus_code': {'compound_code': 'P53J+24 Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHP53J+24'},
#               'rating': 4.4,
#               'reference': 'ChIJY1Zjmsu3JQ0Rwqt-QxhJhY0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1399,
#               'vicinity': 'Avenida Capitão Gaspar de Castro nº 866, Viana do '
#                           'Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.694455, 'lng': -8.8313871},
#                            'viewport': {'northeast': {'lat': 41.6957313302915,
#                                                       'lng': -8.829986769708498},
#                                         'southwest': {'lat': 41.6930333697085,
#                                                       'lng': -8.832684730291502}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'ac95c2735801e2abdb2d0ef3b96a79c483198774',
#               'name': 'Casa Melo Alvim',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2976,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108551735205449714006">Alfredo '
#                                                 'Beleza</a>'],
#                           'photo_reference': 'CmRaAAAACb4m_8R2jIpb_Z-Jqz2teubsVVUqLd93LifIQObNWhm53VAn-UqZrO0rTCwQNQzT0oANnz5cQJWZlMOS9KbgXtVa6JjF3g3vm_JnijF1TsWa4BUB_csh_pQ-Cj6UuFvVEhAKkiLJgFreiMpOQZQ6pdr6GhTyTCX1H5aGdsV5uPxIfx-lv_Wkig',
#                           'width': 3968}],
#               'place_id': 'ChIJd-cd-Su2JQ0RfmJlFDezWxc',
#               'plus_code': {'compound_code': 'M5V9+QC Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5V9+QC'},
#               'rating': 4.5,
#               'reference': 'ChIJd-cd-Su2JQ0RfmJlFDezWxc',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 234,
#               'vicinity': 'Avenida Conde Carreira 28, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.697153, 'lng': -8.8259706},
#                            'viewport': {'northeast': {'lat': 41.6985019802915,
#                                                       'lng': -8.824621619708497},
#                                         'southwest': {'lat': 41.6958040197085,
#                                                       'lng': -8.827319580291501}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '0429e4b36202abfe65e23251ee0835199388e641',
#               'name': 'Hotel Rali Viana',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3191,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106117386555048642465">Hotel '
#                                                 'Rali Viana</a>'],
#                           'photo_reference': 'CmRaAAAArQvBwqiwBHpQSSLWzYcL0Cyn5qNBwLPScAgajqt_Eq-WrgO6omdqJdbL4Jn9dzCjRQmysdtUqx3P37GZ8xCo3-g9YQ9lwDZWx8cP2E2uc2INvB_aNUwn9cjP0hNvv_sjEhBXHP5-lLIPrIvNr5e_DY-2GhRTqMaRfcG1npVjqPoHK-X3rXWNbA',
#                           'width': 5472}],
#               'place_id': 'ChIJ9flDfTK2JQ0RsvN-ZcnMHfo',
#               'plus_code': {'compound_code': 'M5WF+VJ Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5WF+VJ'},
#               'rating': 4,
#               'reference': 'ChIJ9flDfTK2JQ0RsvN-ZcnMHfo',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 726,
#               'vicinity': 'Avenida dom Afonso III 180, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.69634229999999,
#                                         'lng': -8.8285165},
#                            'viewport': {'northeast': {'lat': 41.69767413029149,
#                                                       'lng': -8.827214119708497},
#                                         'southwest': {'lat': 41.69497616970849,
#                                                       'lng': -8.829912080291502}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'f5fc961ed155a166b88e157fccf005320536de05',
#               'name': 'A Vianesa - Guest House',
#               'photos': [{'height': 2976,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/116817635725922186017">Paulo '
#                                                 'freire</a>'],
#                           'photo_reference': 'CmRaAAAAS5HZEg3ei90DFmMBv9LLBuvPxQiSCsHC76s9V4GHAZbR27wEq8jppJ1weNw_90jcmlYnNBWS-SNLMOCQY6-ZxF8hdcwWj4jnQrWz1nyFViQwnEKCFfYVAIjfIJNkqQOREhBHATwpPdmWIVw0yiZgsrEcGhQ6obR8wVKAZNMsHxstkfsYHG7ZKg',
#                           'width': 3968}],
#               'place_id': 'ChIJjcnYUCy2JQ0RTMNiY0WYyhE',
#               'plus_code': {'compound_code': 'M5WC+GH Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5WC+GH'},
#               'rating': 4.3,
#               'reference': 'ChIJjcnYUCy2JQ0RTMNiY0WYyhE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 25,
#               'vicinity': 'Rua Emídio Navarro 35, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.69387810000001,
#                                         'lng': -8.8299015},
#                            'viewport': {'northeast': {'lat': 41.6952297302915,
#                                                       'lng': -8.828554319708498},
#                                         'southwest': {'lat': 41.6925317697085,
#                                                       'lng': -8.831252280291503}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '29a26e71521945174a9b1d8225cca42f3e9c9717',
#               'name': 'Hotel Laranjeira',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115696307349569070968">Stefan '
#                                                 'Riphaus</a>'],
#                           'photo_reference': 'CmRaAAAAdapmD3k7qYaTAEfbW2mC7tR_er_C-zOeG3jc_Bu53gbUg09UMq52WyJ_Yl8MI52jhsich7Et4LH4JMSvP--ijLqfvlQ4jTzH_EvuCDwrqr3EUxt-Str-vpjSXmonm5E6EhBhax4J66dXMXqNz2ItHVDcGhQE1nr3JlUoFg6qPxVAm47Y4u30IA',
#                           'width': 4032}],
#               'place_id': 'ChIJ3fV1ICy2JQ0RKWrJTzMrua0',
#               'plus_code': {'compound_code': 'M5VC+H2 Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5VC+H2'},
#               'rating': 4.4,
#               'reference': 'ChIJ3fV1ICy2JQ0RKWrJTzMrua0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 380,
#               'vicinity': 'Rua Cândido dos Reis 45, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.6972847, 'lng': -8.8238506},
#                            'viewport': {'northeast': {'lat': 41.6986853802915,
#                                                       'lng': -8.822569469708498},
#                                         'southwest': {'lat': 41.6959874197085,
#                                                       'lng': -8.825267430291502}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '3e7c8e5f4656efa2c87a808739d1403c4eef81fa',
#               'name': 'Calatrava Hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2304,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111955118675542509657">Jose '
#                                                 'Juan Lopez</a>'],
#                           'photo_reference': 'CmRZAAAA2MTea-qr9KhtOIJbJld8Rxg2_x2xNR8NmX9ZcaLsjWUVIadoARC3bRnn09MOt9KjVZrPZaViz82kgK8Cg7qCZqOYbZ3jVdnb7UIstLaojzrn8RTqXXvXkB24DDucr7ZHEhB8s3lrmPsfRcRBghryw5hhGhQxkN1_AwOVAGUeFswkiQ2SKHmvSA',
#                           'width': 4096}],
#               'place_id': 'ChIJsRS39DK2JQ0RKpoL80Qo1fA',
#               'plus_code': {'compound_code': 'M5WG+WF Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5WG+WF'},
#               'rating': 3.9,
#               'reference': 'ChIJsRS39DK2JQ0RKpoL80Qo1fA',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 82,
#               'vicinity': 'Rua Manuel Fiúza Júnior 157, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.742881, 'lng': -8.8634901},
#                            'viewport': {'northeast': {'lat': 41.7441735802915,
#                                                       'lng': -8.862128519708499},
#                                         'southwest': {'lat': 41.7414756197085,
#                                                       'lng': -8.864826480291503}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '031899e57671976dace33aeca3fb63083cd53841',
#               'name': 'CasaRada',
#               'photos': [{'height': 3120,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/112425960138318296676">Karl-Heinz '
#                                                 'Lentes</a>'],
#                           'photo_reference': 'CmRaAAAAtA_bJqMVEkH0GOXMV1FU-ZBb8iOXPOo3y_n40e1FmqXESdCl6eB2eOWSc1sXB2UJQ3WIM0ylQGJe-2UeAQ3OKDMc-mrjsb2SJ3lmmjyHoUpgO0LAl-8X8QcWGEY2cbIEEhCMKHjZFH1n9Q31KImYjalAGhThtU1xow5C07wh7wW7ytsY7TS6ng',
#                           'width': 4160}],
#               'place_id': 'ChIJcwAfetzHJQ0RKheyehznkAE',
#               'plus_code': {'compound_code': 'P4VP+5J Carreço, Portugal',
#                             'global_code': '8CHHP4VP+5J'},
#               'rating': 4.3,
#               'reference': 'ChIJcwAfetzHJQ0RKheyehznkAE',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 44,
#               'vicinity': 'Travessa da Vinha Nova 25, Carreço'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.69666669999999,
#                                         'lng': -8.819999999999999},
#                            'viewport': {'northeast': {'lat': 41.69805283029149,
#                                                       'lng': -8.818748319708497},
#                                         'southwest': {'lat': 41.6953548697085,
#                                                       'lng': -8.8214462802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'b7e851bbd0b65250fdf7591fd7b0e3e00d9d6f56',
#               'name': 'Hotel Do Parque',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2976,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104823362515830055540">Jose '
#                                                 'Damiaes</a>'],
#                           'photo_reference': 'CmRaAAAA38mBCZaRnpY_zy_vhXcMvg645953OaR55gykQRgmbycwl80K5kmt_LxCf4LE410LsrXojloSiW5OK8ASoQF8RU32od-a-DnBvkcmISLxAJQtZogICEVTeLGCdvKtTw4OEhD2HkYD0VAuEJxL246Duw04GhSt8sUdEXpCBQDxnzCsZOyfY8SgmA',
#                           'width': 3968}],
#               'place_id': 'ChIJ4WoZwzO2JQ0RE_vZxi69yMw',
#               'plus_code': {'compound_code': 'M5WJ+M2 Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5WJ+M2'},
#               'rating': 4.1,
#               'reference': 'ChIJ4WoZwzO2JQ0RE_vZxi69yMw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1541,
#               'vicinity': 'Praça da Galiza, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.6915947,
#                                         'lng': -8.827486299999999},
#                            'viewport': {'northeast': {'lat': 41.6929134302915,
#                                                       'lng': -8.826120319708497},
#                                         'southwest': {'lat': 41.6902154697085,
#                                                       'lng': -8.828818280291502}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'e0c57f905636e0d020a17c92089970e0b09b8dc6',
#               'name': 'Hotel Jardim Viana',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2048,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115266565825835252127">Hotel '
#                                                 'Jardim Viana</a>'],
#                           'photo_reference': 'CmRaAAAAec9Ls_vy5Q8OnP7YQVE-xZ1OowgHYp8PcuTyfP-zbiqeH-dj0TzYNdU4yNShQrtuk4Becw9R3zlO7T9IUIp4ZdE4pDWD-wQDxJN5G78uO9ixpjq0IoP21LFvf__fbzw5EhDKvBz7TzGOiGkKuY8EaAAEGhSQtXMtFWVvHcqlHkOAWZ3Wd_vuEA',
#                           'width': 1536}],
#               'place_id': 'ChIJQRESpi-2JQ0RloPY_e5v8Yw',
#               'plus_code': {'compound_code': 'M5RF+J2 Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5RF+J2'},
#               'rating': 4.1,
#               'reference': 'ChIJQRESpi-2JQ0RloPY_e5v8Yw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 206,
#               'vicinity': 'Alameda 5 de Outubro no 68, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.6952984, 'lng': -8.823511},
#                            'viewport': {'northeast': {'lat': 41.6966173302915,
#                                                       'lng': -8.822131169708499},
#                                         'southwest': {'lat': 41.6939193697085,
#                                                       'lng': -8.824829130291503}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'ab2e4ab704cdc08d6212e0f7652776d953c50fb5',
#               'name': 'Fábrica do Chocolate | Hotel Chocolataria Museu',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 3264,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115398209815945639683">Vitor '
#                                                 'Torres</a>'],
#                           'photo_reference': 'CmRaAAAArD5RqyPT8C6sJy-V0ZPsrqXMZbzvkilXgj6MBNUmp2IyXrrnODMyta7PDaOLg7lanFgJgWcTjfOUozMSnRhgXSd1nBCQd4vqKe6w_mANLjEVB_woeAlUkDGkuGXFABN6EhB72UTFN_4Omn73p5Ohf2j-GhS_7NYpZNMHjaayQG3lNQE9kUQN3w',
#                           'width': 1836}],
#               'place_id': 'ChIJSWAtOzK2JQ0RvQXwBs9bGNQ',
#               'plus_code': {'compound_code': 'M5WG+4H Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5WG+4H'},
#               'rating': 4.4,
#               'reference': 'ChIJSWAtOzK2JQ0RvQXwBs9bGNQ',
#               'scope': 'GOOGLE',
#               'types': ['museum',
#                         'lodging',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 826,
#               'vicinity': 'Rua do Gontim 70, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.69578, 'lng': -8.825444},
#                            'viewport': {'northeast': {'lat': 41.69712398029151,
#                                                       'lng': -8.824090819708498},
#                                         'southwest': {'lat': 41.69442601970851,
#                                                       'lng': -8.826788780291503}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '9d40505bcfdc9f5b0caa60ce421b2766591acdc4',
#               'name': 'Absoluto design hotel',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 628,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107697625505936258876">Absoluto '
#                                                 'design hotel</a>'],
#                           'photo_reference': 'CmRaAAAAK2cU_exORz1YTLnMnEYvKPVYWOPTIGhTYfyJRDm-Ni2eKWGBM6103SR-sBSFs8jmPFfdhWspxrP-CRQ-68vwpL036YY5RlycNmY8m3QOhCptoSumZIYkBqd6HOnM4PzbEhBNy560hDhxM2z_GTg5p-KBGhQkZAGq14pHIuw8sW_yQRuxRzjPTA',
#                           'width': 900}],
#               'place_id': 'ChIJkQkjiy22JQ0RRgLYlsNoMGg',
#               'plus_code': {'compound_code': 'M5WF+8R Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5WF+8R'},
#               'rating': 4.3,
#               'reference': 'ChIJkQkjiy22JQ0RRgLYlsNoMGg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 90,
#               'vicinity': 'Rua da Bandeira 174, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.6910202, 'lng': -8.8333204},
#                            'viewport': {'northeast': {'lat': 41.6923691802915,
#                                                       'lng': -8.831971419708498},
#                                         'southwest': {'lat': 41.6896712197085,
#                                                       'lng': -8.834669380291501}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'efbaf2db3b16909630ce5c8d4dafa88c51406664',
#               'name': 'Bright Sao Domingos Apartments',
#               'place_id': 'ChIJozci-Si2JQ0RorZVfJuPmYs',
#               'plus_code': {'compound_code': 'M5R8+CM Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5R8+CM'},
#               'reference': 'ChIJozci-Si2JQ0RorZVfJuPmYs',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Região Norte PT, Viela de São Domingos 126 andar 2, '
#                           'Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.6920651, 'lng': -8.831947},
#                            'viewport': {'northeast': {'lat': 41.6933668302915,
#                                                       'lng': -8.830580719708498},
#                                         'southwest': {'lat': 41.6906688697085,
#                                                       'lng': -8.833278680291503}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'cb16b9b9be36fdb825c4f13c79d36d70a6590eb6',
#               'name': 'Casa Manuel Espregueira e Oliveira',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 1536,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102381417658683572677">Elias '
#                                                 'Stadler</a>'],
#                           'photo_reference': 'CmRaAAAA_qWVmsSdQhIp4_LEXhUTk0F089JgYAWwd6wA9Srm21RNwTgOl75IsZDDnkopuVeUHhHxq0Q6VXx5OdXSGy23gyh1ku009ykOxB9Y-VtvU5a-zdbRX6CUVNnfRcmR-rCIEhCPPcEbsrGVEH49u8V0nr9JGhQMYkLX8TCKYEM2Gxy57wBS1qeJUw',
#                           'width': 2048}],
#               'place_id': 'ChIJI_37Iim2JQ0RWnUAikYNks0',
#               'plus_code': {'compound_code': 'M5R9+R6 Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5R9+R6'},
#               'rating': 4.7,
#               'reference': 'ChIJI_37Iim2JQ0RWnUAikYNks0',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 47,
#               'vicinity': 'Rua Manuel Espregueira 190, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.6924561, 'lng': -8.8312303},
#                            'viewport': {'northeast': {'lat': 41.6936802302915,
#                                                       'lng': -8.829818219708496},
#                                         'southwest': {'lat': 41.6909822697085,
#                                                       'lng': -8.8325161802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '2e649603ede054498ee157eabfd10739cd798271',
#               'name': 'Private Room in Old Town',
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/118442993789604422267">areal2004</a>'],
#                           'photo_reference': 'CmRaAAAAEOHnVZ6aAa5f9C5Np6of3QZULfbd94wyvWEZuhwLvn4qPk5TH_ui9fcExuq1Ec_MyctbDS1XVlIT6TkS0qQEdrvHE_dpvDlCO3Cf9axdy29D7A68hM3pooBTQwkcA0OMEhBjfEQr7FO-FI6E4xHAd7fHGhSyx_o2W_Olr2I1DHQsVaV5Rg6qsg',
#                           'width': 4032}],
#               'place_id': 'ChIJh0gwMSm2JQ0RfOnzNALdpeg',
#               'plus_code': {'compound_code': 'M5R9+XG Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5R9+XG'},
#               'rating': 4.6,
#               'reference': 'ChIJh0gwMSm2JQ0RfOnzNALdpeg',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 8,
#               'vicinity': 'Rua da Védoria 24, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.7119637, 'lng': -8.8479986},
#                            'viewport': {'northeast': {'lat': 41.7133505802915,
#                                                       'lng': -8.846620169708498},
#                                         'southwest': {'lat': 41.7106526197085,
#                                                       'lng': -8.849318130291502}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'dbef19d9ce1dad2a089808b80daad68842f82a65',
#               'name': 'Casa Tio',
#               'place_id': 'ChIJT1ugWjvIJQ0R7wWmMl7GW-I',
#               'plus_code': {'compound_code': 'P562+QR Areosa, Portugal',
#                             'global_code': '8CHHP562+QR'},
#               'reference': 'ChIJT1ugWjvIJQ0R7wWmMl7GW-I',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Região Norte PT, Largo das Tílias de Areosa 48, '
#                           'Areosa'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.6939925, 'lng': -8.8297473},
#                            'viewport': {'northeast': {'lat': 41.6953559302915,
#                                                       'lng': -8.828408169708498},
#                                         'southwest': {'lat': 41.6926579697085,
#                                                       'lng': -8.831106130291502}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'aa099b5ce5eaf79b339eef47149773b7d2d597db',
#               'name': 'Coração de Viana',
#               'place_id': 'ChIJm58RnS62JQ0R6T9FfUSeQ0U',
#               'plus_code': {'compound_code': 'M5VC+H4 Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5VC+H4'},
#               'reference': 'ChIJm58RnS62JQ0R6T9FfUSeQ0U',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Rua Cândido dos Reis 26, Viana do Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.69797080000001,
#                                         'lng': -8.825037199999999},
#                            'viewport': {'northeast': {'lat': 41.6993345802915,
#                                                       'lng': -8.823667219708499},
#                                         'southwest': {'lat': 41.6966366197085,
#                                                       'lng': -8.826365180291504}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '6e53a14f1f427f67c1717500f05f22affb1e01f6',
#               'name': 'Villa Margarida',
#               'place_id': 'ChIJlfGNnjK2JQ0RdLr3ZkXjB2I',
#               'plus_code': {'compound_code': 'M5XF+5X Viana do Castelo, '
#                                              'Portugal',
#                             'global_code': '8CHHM5XF+5X'},
#               'rating': 5,
#               'reference': 'ChIJlfGNnjK2JQ0RdLr3ZkXjB2I',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 2,
#               'vicinity': 'Região Norte PT, Rua José Espregueira 71, Viana do '
#                           'Castelo'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 41.7547296, 'lng': -8.861663},
#                            'viewport': {'northeast': {'lat': 41.7560845302915,
#                                                       'lng': -8.860216419708498},
#                                         'southwest': {'lat': 41.7533865697085,
#                                                       'lng': -8.862914380291503}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'fec8150a2caeb44a04280f95d25289335919f60b',
#               'name': 'Albergue Casa do Sardão',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 2208,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/102011783185028798426">Carlos '
#                                                 'Eduardo Dias</a>'],
#                           'photo_reference': 'CmRaAAAAOUfrOmcwSJ5RoWOIqMTmEOpxPcQB5ym-8nkbIlTIMHMSbs3qvG3AKoer7MJOZQi1JlwE7WIyQUSFHxANgNNW0PF4CKdQzNzaQ-mgdev_40s5BmY_wB2TWcpu78T2dDUoEhCVvxH1a-GQemxFL2mgv70AGhTkCQN0oY4kst8Ijh2Mvcv1aZ0fUg',
#                           'width': 3920}],
#               'place_id': 'ChIJ0UM6jcDHJQ0RLYTRMLcaG8A',
#               'plus_code': {'compound_code': 'Q43Q+V8 Carreço, Portugal',
#                             'global_code': '8CHHQ43Q+V8'},
#               'rating': 4.9,
#               'reference': 'ChIJ0UM6jcDHJQ0RLYTRMLcaG8A',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 254,
#               'vicinity': 'Avenida de Paço 769'}],
#  'status': 'OK'}

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
#convert lat/lng to floats: reason is that it will cause an error when trying to plot
hotel_df['Hotel Lat'] = hotel_df['Hotel Lat'].astype(float)
hotel_df['Hotel Lng'] = hotel_df['Hotel Lng'].astype(float)

# %%
#plot heatmap
fig = gmaps.figure()

#create marker layer
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)

#add layers
fig.add_layer(heat_layer)
#heat_layer.max_intensity = max_humidity
fig.add_layer(marker_layer)

#display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
