# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint
#gmaps.configure(api_key="AI...")

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
weather_df_path = "Weather_DF.csv"
weather_df = pd.read_csv(weather_df_path)

weather_df
# Out:
#      Unnamed: 0          City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0             0          Muli   2.92   73.57     84.74        64          45
# 1             1         Togur  58.36   82.83     59.05        87           0
# 2             2       Pitimbu  -7.47  -34.81     82.40        58          20
# 3             3       Ushuaia -54.80  -68.30     33.80        86          40
# 4             4      Hermanus -34.42   19.23     52.00        63          95
# ..          ...           ...    ...     ...       ...       ...         ...
# 575         575        Knysna -34.04   23.05     51.80        53          49
# 576         576        Moerai -22.43 -151.33     68.86        85         100
# 577         577  Port Hedland -20.32  118.57     57.20        50          72
# 578         578         Narón  43.52   -8.15     68.00        72           3
# 579         579          Esim   4.87   -2.24     75.15        86          50
#
#      Wind Speed Country        Date
# 0          0.40      MV  1594667282
# 1          5.55      RU  1594667282
# 2         11.41      BR  1594667282
# 3         27.51      AR  1594666986
# 4          8.99      ZA  1594667225
# ..          ...     ...         ...
# 575       14.99      ZA  1594667396
# 576       15.88      PF  1594667396
# 577        9.17      AU  1594667276
# 578       11.41      ES  1594667397
# 579       11.77      GH  1594667397
#
# [580 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#configure gmaps
gmaps.configure(api_key=g_key)

# %%
#store latitude and longitude in locations
city_locations = weather_df[["Lat","Lng"]]
#store humidity as a variable
humidity = weather_df['Humidity']
max_humidity = max(humidity)
max_humidity
# Out:
# 100

# %%
#plot heatmap
fig = gmaps.figure()

#create heat layer
heat_layer = gmaps.heatmap_layer(city_locations, weights = humidity, dissipating=False, max_intensity=10, point_radius=1)
heat_layer.max_intensity = max_humidity

#add layer
fig.add_layer(heat_layer)

#display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#Narrow down the DataFrame to find your ideal weather condition. For example:
#A max temperature lower than 80 degrees but higher than 70.
#Wind speed less than 10 mph.
#Zero cloudiness.
#Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.

ideal_df = weather_df.loc[(weather_df['Max Temp'] <85) & (weather_df['Max Temp'] > 70) & (weather_df['Wind Speed'] <10) & (weather_df['Cloudiness'] < 5)]
ideal_df
# Out:
#      Unnamed: 0              City    Lat     Lng  Max Temp  Humidity  \
# 32           32          San Jose  37.34 -121.89     82.99        47
# 41           41             Denia  38.84    0.11     80.01        69
# 89           89            Mandan  46.83 -100.89     82.40        69
# 140         140        Viranşehir  37.24   39.76     83.28        29
# 145         145         Caravelas -17.71  -39.25     78.13        68
# 176         176        Susanville  40.42 -120.65     82.00        18
# 185         185         Pestravka  52.41   49.96     79.30        51
# 188         188      Marsá Maţrūḩ  31.35   27.25     78.80        69
# 209         209            Angren  41.02   70.14     73.09        37
# 223         223           Muborak  39.26   65.15     81.45        16
# 275         275          Arnprior  45.43  -76.35     78.01        68
# 284         284         Hong Kong  22.29  114.16     84.99        79
# 289         289    Cap Malheureux -19.98   57.61     71.01        78
# 329         329  Capaccio Paestum  40.42   15.08     75.99        46
# 334         334           Jackson  42.42 -122.83     79.00        44
# 372         372      Villaviciosa  43.48   -5.44     72.00        68
# 377         377              Tete -16.16   33.59     73.40        49
# 515         515         Līsakovsk  52.54   62.49     72.64        49
# 528         528           Chapais  49.78  -74.85     73.40        49
# 541         541         Tamandaré  -8.76  -35.10     79.32        69
# 553         553   Tiznit Province  29.58   -9.50     83.64        37
# 554         554           Lixouri  38.20   20.43     80.60        47
# 558         558          Vallenar -28.57  -70.76     72.90        31
# 567         567        Taiobeiras -15.81  -42.23     78.37        42
#
#      Cloudiness  Wind Speed Country        Date
# 32            1        3.56      US  1594667262
# 41            0        1.01      ES  1594667287
# 89            1        4.70      US  1594667268
# 140           0        7.36      TR  1594667299
# 145           1        6.44      BR  1594667014
# 176           1        3.36      US  1594667156
# 185           0        9.80      RU  1594667305
# 188           0        8.05      EG  1594667305
# 209           3        3.49      UZ  1594667308
# 223           0        0.69      UZ  1594667310
# 275           2        9.51      CA  1594667316
# 284           1        8.99      HK  1594667179
# 289           0        5.99      MU  1594667318
# 329           0        5.99      IT  1594667322
# 334           1        3.09      US  1594667323
# 372           0        5.06      ES  1594667328
# 377           0        5.82      MZ  1594667329
# 515           0        8.86      KZ  1594667346
# 528           1        8.05      CA  1594667371
# 541           0        6.73      BR  1594667392
# 553           4        5.17      MA  1594667394
# 554           0        8.05      GR  1594667394
# 558           0        4.56      CL  1594667394
# 567           3        4.29      BR  1594667154

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#create new hotel DF
hotel_df = ideal_df[["City", "Lat", "Lng", "Country"]].copy()

#add hotel column to df
hotel_df['Hotel Name'] = ""
hotel_df['Hotel Lat'] = ""
hotel_df['Hotel Lng'] = ""

#parameters
#keyword = "hotel"
target_type = "lodging"
radius = 5000

params = {
    #"keyword": keyword,
    "type": target_type,
    "radius": radius,
    "key": g_key
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

for index, row in hotel_df.iterrows():
    
    #set variables for lat and lng to include in parameters. also setting variable for city for each row
    lat = row["Lat"]
    lng = row["Lng"]
    city = row["City"]
    
    #add lat/lng to parameters - values must be a string
    params["location"] = f"{lat},{lng}"
 
    #assemble url and make API request
    print(f"Retrieving results for {city}: ")
    response = requests.get(base_url, params=params).json()
    
    #extract results
    results = response['results']
        
    try:
        print(f"Closest hotel for {city} is {results[0]['name']}.")
        
        #add hotel to Hotel Name column in the df
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
        #add hotel lat and long to dataframe
        hotel_df.loc[index, 'Hotel Lat'] = results[0]['geometry']['location']['lat']
        hotel_df.loc[index, 'Hotel Lng'] = results[0]['geometry']['location']['lng']
                
        
    except(KeyError, IndexError):
        
        #print statement if hotel is not found       
        print("Missing results...skipping")
        
        #if a hotel name is not found, add "N/A" to hotel name field in dataframe
        hotel_df.loc[index, "Hotel Name"] = "N/A"
        
        #if hotel name is not found, default to city coordinates for Lat/Lng fields in the dataframe. The reason
        #for this is that we need to convert the lat/lng to floats and we will get an error if it finds a blank field
        hotel_df.loc[index, "Hotel Lat"] = hotel_df.loc[index,"Lat"]
        hotel_df.loc[index, "Hotel Lng"] = hotel_df.loc[index, "Lng"]
    
    print("---------------")
# Out:
# Retrieving results for San Jose:
# Closest hotel for San Jose is The Westin San Jose.
# ---------------
# Retrieving results for Denia:
# Closest hotel for Denia is Hotel Port Dénia.
# ---------------
# Retrieving results for Mandan:
# Closest hotel for Mandan is Twin City Estates.
# ---------------
# Retrieving results for Viranşehir:
# Closest hotel for Viranşehir is Viranşehir Öğretmenevi.
# ---------------
# Retrieving results for Caravelas:
# Closest hotel for Caravelas is Pousada dos Navegantes.
# ---------------
# Retrieving results for Susanville:
# Closest hotel for Susanville is Red Lion Inn & Suites Susanville.
# ---------------
# Retrieving results for Pestravka:
# Closest hotel for Pestravka is Gostinitsa "Germes".
# ---------------
# Retrieving results for Marsá Maţrūḩ:
# Closest hotel for Marsá Maţrūḩ is Beau Site.
# ---------------
# Retrieving results for Angren:
# Closest hotel for Angren is Sardor Salimovich.
# ---------------
# Retrieving results for Muborak:
# Closest hotel for Muborak is Gostinitsa Prestizh.
# ---------------
# Retrieving results for Arnprior:
# Closest hotel for Arnprior is Country Squire Motel.
# ---------------
# Retrieving results for Hong Kong:
# Closest hotel for Hong Kong is Mini Hotel Central.
# ---------------
# Retrieving results for Cap Malheureux:
# Closest hotel for Cap Malheureux is Pereybere Hotel & Spa.
# ---------------
# Retrieving results for Capaccio Paestum:
# Closest hotel for Capaccio Paestum is Residenza Giancesare B&B Casa Vacanze.
# ---------------
# Retrieving results for Jackson:
# Closest hotel for Jackson is Agate Village Apartments.
# ---------------
# Retrieving results for Villaviciosa:
# Closest hotel for Villaviciosa is Hotel Carlos I.
# ---------------
# Retrieving results for Tete:
# Closest hotel for Tete is Zambeze Paraíso Misterioso.
# ---------------
# Retrieving results for Līsakovsk:
# Closest hotel for Līsakovsk is Gostinitsa "Kontinent".
# ---------------
# Retrieving results for Chapais:
# Closest hotel for Chapais is Hôtel Opémiska.
# ---------------
# Retrieving results for Tamandaré:
# Closest hotel for Tamandaré is Pousada 100 Passos.
# ---------------
# Retrieving results for Tiznit Province:
# Missing results...skipping
# ---------------
# Retrieving results for Lixouri:
# Closest hotel for Lixouri is Summery Hotel.
# ---------------
# Retrieving results for Vallenar:
# Closest hotel for Vallenar is Humacao Bed & Breakfast.
# ---------------
# Retrieving results for Taiobeiras:
# Closest hotel for Taiobeiras is Dallas Hotel.
# ---------------

# %%
pprint(response)
# Out:
# {'html_attributions': [],
#  'results': [{'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.813271,
#                                         'lng': -42.23390089999999},
#                            'viewport': {'northeast': {'lat': -15.8119008697085,
#                                                       'lng': -42.2326198197085},
#                                         'southwest': {'lat': -15.8145988302915,
#                                                       'lng': -42.2353177802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '5f24a944b3d49cbea670ef452aec1203cf50fff6',
#               'name': 'Dallas Hotel',
#               'photos': [{'height': 4000,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/115088085233542504762">Fabiano '
#                                                 'Palhares</a>'],
#                           'photo_reference': 'CmRaAAAARhSFgIGCKAFrbb57ii5URl_mDMsKXAZdgaGtpTd3rJwNM_YBgePHmNjpFrMirEfUEmgk65LGHk3hkOo6VBnMwU57ChB5L0RE9p5nm8OM_4c0PewXqdFibkTrgqQC2oG9EhBlwc2TPikBMVxpy1xer7-FGhQcw62YyMocq989Ol6hVLU4vmRsuQ',
#                           'width': 3000}],
#               'place_id': 'ChIJq58fZUkNTgcRvxhrdE-as6g',
#               'plus_code': {'compound_code': '5QP8+MC Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QP8+MC'},
#               'rating': 4.1,
#               'reference': 'ChIJq58fZUkNTgcRvxhrdE-as6g',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 48,
#               'vicinity': 'Rua Santa Rita de Cássia, 8, Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8131366, 'lng': -42.2338159},
#                            'viewport': {'northeast': {'lat': -15.8117610697085,
#                                                       'lng': -42.2325531697085},
#                                         'southwest': {'lat': -15.8144590302915,
#                                                       'lng': -42.2352511302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '08cb7ca0cd1d4516f580572ba4ff6c796c937071',
#               'name': 'Setting Sun Inn',
#               'photos': [{'height': 720,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/106918094726555739726">Pousada '
#                                                 'Sol Poente</a>'],
#                           'photo_reference': 'CmRaAAAAYx0JqKKAVRK7Ht8MudPnZaSLDnPSKUWQtApMm_R1lo8yo0oW7NnuK346IaU1rANE-5R3Tyi8p004RE2Qwzxcs1iJAKGEbZH-0356wvT6bykg20JWSpGFLdz7ScTcPH6zEhAKA076oOdVH0BEkOeGah6_GhQWW9SSYs7NipHO-GvhdMEhl8PWBg',
#                           'width': 960}],
#               'place_id': 'ChIJu11ZK2fDtpQR6rrwDA3h8eA',
#               'plus_code': {'compound_code': '5QP8+PF Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QP8+PF'},
#               'rating': 4.5,
#               'reference': 'ChIJu11ZK2fDtpQR6rrwDA3h8eA',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 21,
#               'vicinity': 'Rua Santa Rita de Cássia, 22 - Centro, Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8151858, 'lng': -42.2282068},
#                            'viewport': {'northeast': {'lat': -15.8138577697085,
#                                                       'lng': -42.22686896970849},
#                                         'southwest': {'lat': -15.8165557302915,
#                                                       'lng': -42.22956693029149}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'eb04f65f83f3db512725a4d9d3cd6e6353a3e249',
#               'name': 'Hotel Taiobeiras',
#               'photos': [{'height': 1080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/111754356396191501776">Octavio '
#                                                 'de Chermont Rayol Neto</a>'],
#                           'photo_reference': 'CmRaAAAAYzhHMDW8A41pqbyzmd4qSDsJfHLEm9AmC38xqpYJxt-S9jhRq2JvV_DrCjs0T-R7NTxlx7W6CbdNDwuXEdT8DBVSDtDs6DsOGIsORk8Bwp09MFxH2CQxZ-hGOUGI28QIEhAyhEwyYApzuY0G_zfDMBc_GhRHdH3Ch0dsPIhDCBqY-BPG6UNlMQ',
#                           'width': 1920}],
#               'place_id': 'ChIJoa3OOs9yTgcR8-7pUPifaNw',
#               'plus_code': {'compound_code': '5QMC+WP Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QMC+WP'},
#               'rating': 4.1,
#               'reference': 'ChIJoa3OOs9yTgcR8-7pUPifaNw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 85,
#               'vicinity': 'Rua Pedra Azul, 55 - Centro, Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8099495, 'lng': -42.2236324},
#                            'viewport': {'northeast': {'lat': -15.8086693697085,
#                                                       'lng': -42.22231121970849},
#                                         'southwest': {'lat': -15.8113673302915,
#                                                       'lng': -42.22500918029149}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '9021c22f928de528cfc8ff173cf177fbde982d88',
#               'name': 'Hotel Avenida',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 900,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/117058219300413612092">Edilene '
#                                                 'Mendes</a>'],
#                           'photo_reference': 'CmRaAAAAYbIjhESNeXR5dlF6pJ9uoXk7h3m0BLpnXnVu4QnNREI8n58JYAUmKMDaLIK-xZYr9jpGUdB-ffwNvtJMtMBBdaoS2234sbfesZHVQct_XBfGe8XkKjzJpFcEdki-QFWxEhBWjBLy5pzktiEg0c6h0bz_GhQtm3l3KidmmKyf1GreWln5zGKDXw',
#                           'width': 1600}],
#               'place_id': 'ChIJSySti7hyTgcRDzro2L2u5G8',
#               'plus_code': {'compound_code': '5QRG+2G Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QRG+2G'},
#               'rating': 4.4,
#               'reference': 'ChIJSySti7hyTgcRDzro2L2u5G8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 195,
#               'vicinity': 'Avenida Caiçara, 1221, Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8136387, 'lng': -42.230522},
#                            'viewport': {'northeast': {'lat': -15.8123227197085,
#                                                       'lng': -42.2291898697085},
#                                         'southwest': {'lat': -15.8150206802915,
#                                                       'lng': -42.2318878302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '50edfe3cb60ec14cdda8ae80ace541d9ab8a8364',
#               'name': 'Hotel Brasília Taiobeiras',
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJoYOGTslyTgcR_c40A9cryP8',
#               'plus_code': {'compound_code': '5QP9+GQ Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QP9+GQ'},
#               'rating': 3.5,
#               'reference': 'ChIJoYOGTslyTgcR_c40A9cryP8',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 22,
#               'vicinity': 'Avenida da Liberdade, 519-A - Centro, Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8137261, 'lng': -42.2313809},
#                            'viewport': {'northeast': {'lat': -15.81234671970849,
#                                                       'lng': -42.2300149197085},
#                                         'southwest': {'lat': -15.8150446802915,
#                                                       'lng': -42.2327128802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '74dfd4ac1191ad86115d2ba03700b6720ceff143',
#               'name': "D'Gust Hotel",
#               'photos': [{'height': 1280,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100418381073805855543">Junior '
#                                                 'Dias</a>'],
#                           'photo_reference': 'CmRaAAAASwpwonwAZ2XFqUywxNFqlGqfDyv9x3a4ZtuL6MLm6cKT35nto9HRHI0n0MSiEXNtp4TFS3D0OcR2BXMKwbkg_4RpalXhxEtEAxdUK66py0-u8_JDLT_xolzLtHqp5YUMEhCvqFoOw69OjvFSNnEYOYIcGhTcE8e0BTE9Qo7ovdPS-GvnU1ayaQ',
#                           'width': 720}],
#               'place_id': 'ChIJ74GxNB9zTgcRtcyBUEc4yJw',
#               'plus_code': {'compound_code': '5QP9+GC Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QP9+GC'},
#               'reference': 'ChIJ74GxNB9zTgcRtcyBUEc4yJw',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Avenida da Liberdade, 442 - 1 Andar - Centro, '
#                           'Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8080643, 'lng': -42.2200858},
#                            'viewport': {'northeast': {'lat': -15.80677291970849,
#                                                       'lng': -42.2187618697085},
#                                         'southwest': {'lat': -15.8094708802915,
#                                                       'lng': -42.22145983029149}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'f98e1499a708967d26b19466acfbcc3f61638d56',
#               'name': 'Osmanodecco',
#               'place_id': 'ChIJS9UbsnBzTgcRRBLJw0UCYZQ',
#               'plus_code': {'compound_code': '5QRH+QX Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QRH+QX'},
#               'reference': 'ChIJS9UbsnBzTgcRRBLJw0UCYZQ',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'vicinity': 'Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8198364, 'lng': -42.2258807},
#                            'viewport': {'northeast': {'lat': -15.8185436197085,
#                                                       'lng': -42.2245675197085},
#                                         'southwest': {'lat': -15.8212415802915,
#                                                       'lng': -42.2272654802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png',
#               'id': 'bd49135440b4bcecba6d7ecda33403909b8d512b',
#               'name': 'Bom Cãopanheiro Pet Shop',
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJFSbOoM5yTgcRnOF6gXDTdlQ',
#               'plus_code': {'compound_code': '5QJF+3J Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QJF+3J'},
#               'rating': 4.5,
#               'reference': 'ChIJFSbOoM5yTgcRnOF6gXDTdlQ',
#               'scope': 'GOOGLE',
#               'types': ['pet_store',
#                         'lodging',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 13,
#               'vicinity': 'Igreja Nossa Senhora de Fátima - Avenida do '
#                           'Contôrno, 1605, Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8075114, 'lng': -42.2174722},
#                            'viewport': {'northeast': {'lat': -15.8062079697085,
#                                                       'lng': -42.2160132197085},
#                                         'southwest': {'lat': -15.8089059302915,
#                                                       'lng': -42.2187111802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '262f0369eb680c98c081778c7f6969984f5bae47',
#               'name': 'Motel Village',
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJ4Sta471yTgcRAx67blGLTO4',
#               'plus_code': {'compound_code': '5QRM+X2 Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QRM+X2'},
#               'rating': 5,
#               'reference': 'ChIJ4Sta471yTgcRAx67blGLTO4',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': 'Avenida do Contorno, 3675 - Centro, Avenida do '
#                           'Contôrno, 3675, Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.807483, 'lng': -42.2174301},
#                            'viewport': {'northeast': {'lat': -15.8063017197085,
#                                                       'lng': -42.21615101970851},
#                                         'southwest': {'lat': -15.8089996802915,
#                                                       'lng': -42.2188489802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': '63e248bed3b3497c74a3916975b44bf7c1e869f8',
#               'name': 'Pousada Village',
#               'photos': [{'height': 2592,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103068726119532303507">Antonio '
#                                                 'Nazareth Jr.</a>'],
#                           'photo_reference': 'CmRaAAAAXXuBIE8UGvH1WfoJ1UXDJdGsmYnuEb4A4-6_NTywhLlfkl_5PJPmzGUWdYd-RjzUhw9rKpkNskCElV0iiVpHQzy07C1qYc6Ecd1o_pqxEJSQdXY6g0eILhDB5IIiwGwIEhC3kwW37wP4IriN55KYNl8vGhR4oVl8S57COsxE1fg1EcVrVPOoqw',
#                           'width': 4608}],
#               'place_id': 'ChIJa-gS471yTgcR56ZYjP0btok',
#               'plus_code': {'compound_code': '5QVM+22 Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QVM+22'},
#               'rating': 4.1,
#               'reference': 'ChIJa-gS471yTgcR56ZYjP0btok',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 28,
#               'vicinity': 'Rua Pernambuco, 783, Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8073366,
#                                         'lng': -42.21739089999999},
#                            'viewport': {'northeast': {'lat': -15.8056104197085,
#                                                       'lng': -42.2159063197085},
#                                         'southwest': {'lat': -15.8083083802915,
#                                                       'lng': -42.2186042802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'e40df451c8eab402cebf508600c02cb23a2813db',
#               'name': 'Hotel Village',
#               'photos': [{'height': 3024,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104918199358414219935">LIZZ '
#                                                 'CARDOSO - Lizz Paolla</a>'],
#                           'photo_reference': 'CmRaAAAA5SCt8gpRpA2ToTofkAIw-xA6UnaqWyu57fzwogbrhazab9Qyt92abtuEiqIFJ23pYw4YKwA6_7NVQMJ5sZaa8ZLlH2u4INWtXmCf0SXhlS75Nk2dr_FjRhHi6K2gizCfEhBEWdiOAG1-hmiCz50EfZ2gGhQ84h_D7p91dHwcvd3SAGFZ7UNjXQ',
#                           'width': 4032}],
#               'place_id': 'ChIJZY2WxDpzTgcRfVfGz_Nff8o',
#               'plus_code': {'compound_code': '5QVM+32 Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5QVM+32'},
#               'rating': 4.3,
#               'reference': 'ChIJZY2WxDpzTgcRfVfGz_Nff8o',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 36,
#               'vicinity': 'Avenida do Contorno, Taiobeiras'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': -15.8403675, 'lng': -42.2103107},
#                            'viewport': {'northeast': {'lat': -15.83907226970849,
#                                                       'lng': -42.20889311970851},
#                                         'southwest': {'lat': -15.8417702302915,
#                                                       'lng': -42.2115910802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#               'id': 'e637cef9d02b81d3d8a4dc6e21daaea832c54f57',
#               'name': 'LIBERTY MOTEL',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 2592,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/103068726119532303507">Antonio '
#                                                 'Nazareth Jr.</a>'],
#                           'photo_reference': 'CmRaAAAAAIpS0CRBCb9v51OP2hoUr6vxxem0hmHZ3nkg6mmhR1t0Cjo43wBvQv2oUxPv_DA_r-nCujDKcQ0YX7-20ZF8MBtoQ1K94sQn6GogwukjzFuQD7WzsLTIb8Mq2GFKPmmFEhAQI6_rcoDUWqzt6VHQHWCZGhTNY2tcpG3rqwUuL734YS0MF4qn2w',
#                           'width': 4608}],
#               'place_id': 'ChIJLWoYSBpzTgcRXyZFcxdqGHY',
#               'plus_code': {'compound_code': '5Q5Q+VV Taiobeiras, State of '
#                                              'Minas Gerais, Brazil',
#                             'global_code': '58PV5Q5Q+VV'},
#               'rating': 4.5,
#               'reference': 'ChIJLWoYSBpzTgcRXyZFcxdqGHY',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 14,
#               'vicinity': 'ROD LMG 404 KM 43 ESQ, Taiobeiras'}],
#  'status': 'OK'}

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
#convert lat/lng to floats: reason is that it will cause an error when trying to plot
hotel_df['Hotel Lat'] = hotel_df['Hotel Lat'].astype(float)
hotel_df['Hotel Lng'] = hotel_df['Hotel Lng'].astype(float)

# %%
#plot heatmap
fig = gmaps.figure()

#create marker layer
marker_layer = gmaps.marker_layer(locations, info_box_content = hotel_info)

#add layers
fig.add_layer(heat_layer)
heat_layer.max_intensity = max_humidity
fig.add_layer(marker_layer)

#display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
